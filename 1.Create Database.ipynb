# %%
# %sql
use catalog learning_spark_sql;
create schema if not exists first_db;

# %%
# %sql
describe database first_db;

# %%
# %sql
create table if not exists learning_spark_sql.first_db.first_table (id int, name string);
insert into learning_spark_sql.first_db.first_table values (1, 'John'), (2, 'Jane');
    
select * from learning_spark_sql.first_db.first_table;

# %%
# %sql
describe schema extended learning_spark_sql.first_db;
